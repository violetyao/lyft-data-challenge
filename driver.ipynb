# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
drivers = pd.read_csv("data/driver_ids.csv")

# %%
drivers.head()
# Out:
#                           driver_id  driver_onboard_date
# 0  002be0ffdc997bd5c50703158b7c2491  2016-03-29 00:00:00
# 1  007f0389f9c7b03ef97098422f902e62  2016-03-29 00:00:00
# 2  011e5c5dfc5c2c92501b8b24d47509bc  2016-04-05 00:00:00
# 3  0152a2f305e71d26cc964f8d4411add9  2016-04-23 00:00:00
# 4  01674381af7edd264113d4e6ed55ecda  2016-04-29 00:00:00

# %%
drivers = drivers["driver_id"].tolist()

# %%
len(drivers)
# Out:
# 937

# %%
random.shuffle(drivers)

# %%
def graph_multi_driver(id_list):
    # gca stands for 'get current axis'
    ax = plt.gca()

    for i in id_list:
        path = "driver/"+ i + ".csv"
        driver = pd.read_csv(path)
        driver = driver.drop(['Unnamed: 0'], axis=1)
        
        driver["start"] = "2016-03-28 00:00:00"
        driver["date"] = pd.to_datetime(driver["date"])
        driver["start"] = pd.to_datetime(driver["start"])
        driver['diff'] = driver['date'] - driver['start']
        driver["diff"] = driver["diff"].dt.days
        driver = driver.sort_values(by="diff")
        print(driver.head())
        
        driver.plot(kind='line',x='diff',y='fare',ax=ax)
    plt.show()

# %%
graph_multi_driver(drivers[15:20])
# Out:
#         date    fare      start  diff
# 6 2016-04-05   86.97 2016-03-28     8
# 9 2016-04-06   80.30 2016-03-28     9
# 3 2016-04-08   99.74 2016-03-28    11
# 5 2016-04-09  163.65 2016-03-28    12
# 1 2016-04-11  113.93 2016-03-28    14
#          date   fare      start  diff
# 43 2016-03-28   7.12 2016-03-28     0
# 19 2016-03-29  21.00 2016-03-28     1
# 21 2016-03-30  46.41 2016-03-28     2
# 39 2016-03-31  17.34 2016-03-28     3
# 45 2016-04-02  28.45 2016-03-28     5
#         date    fare      start  diff
# 2 2016-04-07   72.32 2016-03-28    10
# 3 2016-04-08   89.30 2016-03-28    11
# 1 2016-04-16  119.59 2016-03-28    19
# 5 2016-04-19   32.88 2016-03-28    22
# 0 2016-04-25   19.21 2016-03-28    28
#          date    fare      start  diff
# 37 2016-05-07   92.43 2016-03-28    40
# 29 2016-05-08  178.91 2016-03-28    41
# 13 2016-05-09  180.14 2016-03-28    42
# 6  2016-05-10  198.97 2016-03-28    43
# 24 2016-05-11  281.18 2016-03-28    44
#          date    fare      start  diff
# 15 2016-04-14   74.17 2016-03-28    17
# 26 2016-04-15   13.95 2016-03-28    18
# 30 2016-04-18   44.97 2016-03-28    21
# 23 2016-04-22  191.28 2016-03-28    25
# 35 2016-04-23   15.72 2016-03-28    26
